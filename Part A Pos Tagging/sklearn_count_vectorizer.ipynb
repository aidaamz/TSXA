# %%
from sklearn.feature_extraction.text import CountVectorizer
from pathlib import Path

text = Path('Data_1.txt').read_text(encoding='utf-8')

print("Text from Data_1.txt:")
print(text)

# create a list of documents with CountVectorizer
corpus = [text]

vectorizer = CountVectorizer(
    lowercase=True,
    stop_words='english',
    ngram_range=(1, 2), # single words + two-word phrases
    min_df=1, # keep words appearing in at least 1 document
)

# Tokenize and build vocabaulary and count words
X = vectorizer.fit_transform(corpus)

tokens = vectorizer.build_analyzer()(text)
features = vectorizer.get_feature_names_out()

print("\nTokens after preprocessing:")
print(tokens)

print("\nVocabulary:")
print(features)

print("\nWord counts:")
for word, count in zip(features, X.toarray()[0]):
    print(f"{word}: {count}")
# Out:
# Text from Data_1.txt:
# Classification is the task of choosing the correct class label for a given input. In basic
# classification tasks, each input is considered in isolation from all other inputs, and the set of labels is defined in advance. The basic classification task has a number of interesting variants. For example, in multiclass classification, each instance may be assigned multiple labels; in open-class classification, the set of labels is not defined in advance; and in sequence classification, a list of inputs are jointly classified.
#
# Tokens after preprocessing:
# ['classification', 'task', 'choosing', 'correct', 'class', 'label', 'given', 'input', 'basic', 'classification', 'tasks', 'input', 'considered', 'isolation', 'inputs', 'set', 'labels', 'defined', 'advance', 'basic', 'classification', 'task', 'number', 'interesting', 'variants', 'example', 'multiclass', 'classification', 'instance', 'assigned', 'multiple', 'labels', 'open', 'class', 'classification', 'set', 'labels', 'defined', 'advance', 'sequence', 'classification', 'list', 'inputs', 'jointly', 'classified', 'classification task', 'task choosing', 'choosing correct', 'correct class', 'class label', 'label given', 'given input', 'input basic', 'basic classification', 'classification tasks', 'tasks input', 'input considered', 'considered isolation', 'isolation inputs', 'inputs set', 'set labels', 'labels defined', 'defined advance', 'advance basic', 'basic classification', 'classification task', 'task number', 'number interesting', 'interesting variants', 'variants example', 'example multiclass', 'multiclass classification', 'classification instance', 'instance assigned', 'assigned multiple', 'multiple labels', 'labels open', 'open class', 'class classification', 'classification set', 'set labels', 'labels defined', 'defined advance', 'advance sequence', 'sequence classification', 'classification list', 'list inputs', 'inputs jointly', 'jointly classified']
#
# Vocabulary:
# ['advance' 'advance basic' 'advance sequence' 'assigned'
#  'assigned multiple' 'basic' 'basic classification' 'choosing'
#  'choosing correct' 'class' 'class classification' 'class label'
#  'classification' 'classification instance' 'classification list'
#  'classification set' 'classification task' 'classification tasks'
#  'classified' 'considered' 'considered isolation' 'correct'
#  'correct class' 'defined' 'defined advance' 'example'
#  'example multiclass' 'given' 'given input' 'input' 'input basic'
#  'input considered' 'inputs' 'inputs jointly' 'inputs set' 'instance'
#  'instance assigned' 'interesting' 'interesting variants' 'isolation'
#  'isolation inputs' 'jointly' 'jointly classified' 'label' 'label given'
#  'labels' 'labels defined' 'labels open' 'list' 'list inputs' 'multiclass'
#  'multiclass classification' 'multiple' 'multiple labels' 'number'
#  'number interesting' 'open' 'open class' 'sequence'
#  'sequence classification' 'set' 'set labels' 'task' 'task choosing'
#  'task number' 'tasks' 'tasks input' 'variants' 'variants example']
#
# Word counts:
# advance: 2
# advance basic: 1
# advance sequence: 1
# assigned: 1
# assigned multiple: 1
# basic: 2
# basic classification: 2
# choosing: 1
# choosing correct: 1
# class: 2
# class classification: 1
# class label: 1
# classification: 6
# classification instance: 1
# classification list: 1
# classification set: 1
# classification task: 2
# classification tasks: 1
# classified: 1
# considered: 1
# considered isolation: 1
# correct: 1
# correct class: 1
# defined: 2
# defined advance: 2
# example: 1
# example multiclass: 1
# given: 1
# given input: 1
# input: 2
# input basic: 1
# input considered: 1
# inputs: 2
# inputs jointly: 1
# inputs set: 1
# instance: 1
# instance assigned: 1
# interesting: 1
# interesting variants: 1
# isolation: 1
# isolation inputs: 1
# jointly: 1
# jointly classified: 1
# label: 1
# label given: 1
# labels: 3
# labels defined: 2
# labels open: 1
# list: 1
# list inputs: 1
# multiclass: 1
# multiclass classification: 1
# multiple: 1
# multiple labels: 1
# number: 1
# number interesting: 1
# open: 1
# open class: 1
# sequence: 1
# sequence classification: 1
# set: 2
# set labels: 2
# task: 2
# task choosing: 1
# task number: 1
# tasks: 1
# tasks input: 1
# variants: 1
# variants example: 1

# %%
from sklearn.feature_extraction.text import CountVectorizer

with open('Data_1.txt', 'r', encoding='utf-8') as file:
    corpus = file.read()
    
print("Text from Data_1.txt:")
print(corpus)

vectorizer = CountVectorizer(lowercase=True, stop_words='english')

analyzer = vectorizer.build_analyzer()

tokens = analyzer(corpus)

print("\nTokens after preprocessing:")
print(tokens)
# Out:
# Text from Data_1.txt:
# Classification is the task of choosing the correct class label for a given input. In basic
# classification tasks, each input is considered in isolation from all other inputs, and the set of labels is defined in advance. The basic classification task has a number of interesting variants. For example, in multiclass classification, each instance may be assigned multiple labels; in open-class classification, the set of labels is not defined in advance; and in sequence classification, a list of inputs are jointly classified.
#
# Tokens after preprocessing:
# ['classification', 'task', 'choosing', 'correct', 'class', 'label', 'given', 'input', 'basic', 'classification', 'tasks', 'input', 'considered', 'isolation', 'inputs', 'set', 'labels', 'defined', 'advance', 'basic', 'classification', 'task', 'number', 'interesting', 'variants', 'example', 'multiclass', 'classification', 'instance', 'assigned', 'multiple', 'labels', 'open', 'class', 'classification', 'set', 'labels', 'defined', 'advance', 'sequence', 'classification', 'list', 'inputs', 'jointly', 'classified']
